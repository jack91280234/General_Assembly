# %% [markdown]
# # Capstone Part 2 Health Dataset
# ----
# ### Requirements
# 1) Find and Clean Your Data: Source and format the required data for your project.
# * Create a database
# * Create a data dictionary
#
# 2) Perform preliminary data munging and cleaning of your data: organize your data relevant to your project goals.
# * Review data to verify initial assumptions
# * Clean and munge data as necessary
#
# 3) Describe your data: keep your intended audience(s) in mind.
# * Document your work so far in a Jupyter notebook.
#
# ### Bonus
# 4) Document your project goals (revise from your initial pitch)
# * Articulate “Specific aim”
# * Outline proposed methods and models
# * Define risks & assumptions
#
# 5) Create a blog post of at least 500 words that describes your work so far. Link to it in your Jupyter notebook.

# %% [markdown]
# # Dataset URLS
# ***
# ### Dataset Origin
# URL : https://wwwn.cdc.gov/nchs/nhanes/continuousnhanes/default.aspx?BeginYear=2015
#
# ### Dataset Data Dictionary
#
# __Demographics URL :__
# * [Demographic Variables and Sample Weights](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DEMO_I.htm)
#
# __Examination URLS :__
# * [Blood Pressure](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/BPX_I.htm)
# * [Body Measures](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/BMX_I.htm)
#
#
# __Labs URLS :__
# * [Albumin & Creatinine - Urine](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/ALB_CR_I.htm)
# * [Cholesterol - High-Density Lipoprotein (HDL)](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HDL_I.htm)
# * [Cholesterol - Total](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/TCHOL_I.htm)
# * [Chromium & Cobalt](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/CRCO_I.htm)
# * [Complete Blood Count with 5-Part Differential - Whole Blood](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/CBC_I.htm)
# * [Fasting Questionnaire](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/FASTQX_I.htm)
# * [Fluoride - Plasma](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/FLDEP_I.htm)
# * [Fluoride - Water](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/FLDEW_I.htm)
# * [Glycohemoglobin](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/GHB_I.htm)
# * [Hepatitis A](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HEPA_I.htm)
# * [Hepatitis B: Core antibody, Surface antigen, and Hepatitis D antibody](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HEPBD_I.htm)
# * [Hepatitis B: Surface Antibody](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HEPB_S_I.htm)
# * [Hepatitis C: RNA (HCV-RNA) and Hepatitis C Genotype](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HEPC_I.htm)
# * [Hepatitis E: IgG & IgM Antibodies](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HEPE_I.htm)
# * [Herpes Simplex Virus Type-1 & Type-2](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HSV_I.htm)
# * [HIV Antibody Test](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HIV_I.htm)
# * [Standard Biochemistry Profile](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/BIOPRO_I.htm)
# * [Trichomonas - Urine](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/TRICH_I.htm)
# * [Urinary Chlamydia](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/CHLMDA_I.htm)
# * [Urine Flow Rate](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/UCFLOW_I.htm)
# * [Urine Pregnancy Test](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/UCPREG_I.htm)
#
# __Questionaire URLS :__
# * [Acculturation](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/ACQ_I.htm)
# * [Blood Pressure & Cholesterol](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/BPQ_I.htm)
# * [Cardiovascular Health](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/CDQ_I.htm)
# * [Current Health Status](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HSQ_I.htm)
# * [Dermatology](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DEQ_I.htm)
# * [Diabetes](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DIQ_I.htm)
# * [Disability](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DLQ_I.htm)
# * [Early Childhood](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/ECQ_I.htm)
# * [Health Insurance](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HIQ_I.htm)
# * [Hepatitis](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HEQ_I.htm)
# * [Hospital Utilization & Access to Care](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HUQ_I.htm)
# * [Housing Characteristics](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/HOQ_I.htm)
# * [Immunization](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/IMQ_I.htm)
# * [Income](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/INQ_I.htm)
# * [Medical Conditions](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/MCQ_I.htm)
# * [Mental Health - Depression Screener](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DPQ_I.htm)
# * [Oral Health](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/OHQ_I.htm)
# * [Physical Activity](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/PAQ_I.htm)
# * [Physical Functioning](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/PFQ_I.htm)
# * [Sexual Behavior](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/SXQ_I.htm)
# * [Smoking - Cigarette Use](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/SMQ_I.htm)
# * [Smoking - Household Smokers](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/SMQFAM_I.htm)
# * [Smoking - Recent Tobacco Use](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/SMQRTU_I.htm)
# * [Smoking - Secondhand Smoke Exposure](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/SMQSHS_I.htm)

# %% [markdown]
# # Dataset EDA

# %%
# Importing tools for data cleaning and analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Loading xpt files into pandas

# Demographic dataset
demographic = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/demographics/DEMO_I.XPT')

# Examination Datasets
blood_pressure = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/examination_data/BPX_I.XPT')
body_measures = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/examination_data/BMX_I.XPT')

# Lab Datasets
albumin_and_creatinine_urine = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/ALB_CR_I.XPT')
high_density_lipoprotein = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/HDL_I.XPT')
cholesterol_total = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/TCHOL_I.XPT')
chromium_and_cobalt = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/CRCO_I.XPT')
complete_blood_count = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/CBC_I.XPT')
fasting_questionnaire = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/FASTQX_I.XPT')
fluoride_plasma = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/FLDEP_I.XPT')
fluoride_water = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/FLDEW_I.XPT')
glycohemoglobin = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/GHB_I.XPT')
hepatitis_A = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/HEPA_I.XPT')
hepatitis_B_core_antibody_and_hepatitis_D_antibody = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/HEPBD_I.XPT')
hepatitis_B_surface_antibody = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/HEPB_S_I.XPT')
hepatitis_C = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/HEPC_I.XPT')
hepatitis_E = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/HEPE_I.XPT')
herpes_simplex_virus = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/HSV_I.XPT')
hiv_antibody_test = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/HIV_I.XPT')
standard_biochemistry_profile = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/BIOPRO_I.XPT')
trichomonas_urine = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/TRICH_I.XPT')
urinary_chlamydia = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/CHLMDA_I.XPT')
urine_flow_rate	 = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/UCFLOW_I.XPT')
urine_pregnancy_test = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/lab_data/UCPREG_I.XPT')

# Questionaire Datasets
acculturation = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/ACQ_I.XPT')
blood_pressure_and_cholesterol = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/BPQ_I.XPT')
cardiovascular_health = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/CDQ_I.XPT')
current_health_status = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/HSQ_I.XPT')
dermatology	 = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/DEQ_I.XPT')
diabetes = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/DIQ_I.XPT')
disability = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/DLQ_I.XPT')
early_childhood = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/ECQ_I.XPT')
health_insurance = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/HIQ_I.XPT')
hepatitis = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/HEQ_I.XPT')
hospital_utilization_and_access_to_care = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/HUQ_I.XPT')
housing_characteristics = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/HOQ_I.XPT')
immunization = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/IMQ_I.XPT')
income = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/INQ_I.XPT')
medical_conditions = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/MCQ_I.XPT')
mental_health_depression_screener = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/DPQ_I.XPT')
oral_health = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/OHQ_I.XPT')
physical_activity = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/PAQ_I.XPT')
physical_functioning = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/PFQ_I.XPT')
sexual_behavior = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/SXQ_I.XPT')
smoking_cigarette_use = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/SMQ_I.XPT')
smoking_household_smokers = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/SMQFAM_I.XPT')
smoking_recent_tobacco_use = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/SMQRTU_I.XPT')
smoking_secondhand_smoke_exposure = pd.read_sas('./national_health_and_nutrition_examination_survey_2015_2016/questionaire/SMQSHS_I.XPT')

# %%
demographic.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  83732.0       9.0       2.0       1.0      62.0       NaN       3.0
# 1  83733.0       9.0       2.0       1.0      53.0       NaN       3.0
# 2  83734.0       9.0       2.0       1.0      78.0       NaN       3.0
# 3  83735.0       9.0       2.0       2.0      56.0       NaN       3.0
# 4  83736.0       9.0       2.0       2.0      42.0       NaN       4.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM    ...     DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0       3.0       1.0       NaN    ...          5.0       1.0       3.0
# 1       3.0       1.0       NaN    ...          3.0       3.0       NaN
# 2       3.0       2.0       NaN    ...          3.0       1.0       3.0
# 3       3.0       2.0       NaN    ...          5.0       6.0       NaN
# 4       4.0       2.0       NaN    ...          4.0       3.0       NaN
#
#         WTINT2YR       WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# ...

# %%
demographic.shape
# Out:
# (9971, 47)

# %%
demographic_merge_current_health_status = demographic.merge(current_health_status, how = 'inner', on = 'SEQN')

# %%
demographic_merge_current_health_status.shape
# Out:
# (9165, 55)

# %%
tempdf = demographic_merge_current_health_status.iloc[demographic_merge_current_health_status['HSD010'].dropna(), :]

# %%
tempdf.corr()
# Out:
#               SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  \
# SEQN      1.000000       NaN       NaN  0.832253 -0.503570       NaN
# SDDSRVYR       NaN       NaN       NaN       NaN       NaN       NaN
# RIDSTATR       NaN       NaN       NaN       NaN       NaN       NaN
# RIAGENDR  0.832253       NaN       NaN  1.000000 -0.702754       NaN
# RIDAGEYR -0.503570       NaN       NaN -0.702754  1.000000       NaN
# RIDAGEMN       NaN       NaN       NaN       NaN       NaN       NaN
# RIDRETH1  0.168036       NaN       NaN  0.178123 -0.590626       NaN
# RIDRETH3  0.168036       NaN       NaN  0.178123 -0.590626       NaN
# RIDEXMON  0.316915       NaN       NaN  0.308838  0.048443       NaN
# RIDEXAGM       NaN       NaN       NaN       NaN       NaN       NaN
# DMQMILIZ  0.495651       NaN       NaN  0.795865 -0.874213       NaN
# DMQADFC        NaN       NaN       NaN       NaN       NaN       NaN
# DMDBORN4 -0.316915       NaN       NaN -0.308838 -0.048443       NaN
# ...

# %%
fig, ax = plt.subplots(figsize = (20,15))

# %%
fig, ax = plt.subplots(figsize = (20,15))
sns.jointplot()
